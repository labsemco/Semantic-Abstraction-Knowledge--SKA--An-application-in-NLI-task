# %%
import pandas as pd
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu

# %%
ruta="../"
models=["gemma2:2b","gemma2","llama3.2","llama3.1","phi3:medium","phi3"]#,"phi3"]
corpus=["Scitail","RTEGLUE"]
labels=["Entail_f1","Contra_f1"]

# %%
new_data={"model":[],"corpus":[],"label":[],
          "base_avg":[],"base_std":[],"base_std0":[],
          "SKA_DT_avg":[],"SKA_DT_std":[],"SKA_DT_std0":[],"p_value_SKA_DT":[],
          "SKA_MV_avg":[],"p_value_SKA_MV":[],"SKA_MV_std":[],"SKA_MV_std0":[],
          "SAoT_avg":[],"p_value_SAoT":[],"SAoT_std":[],"SAoT_std0":[],
          "SAoT_FS_avg":[],"p_value_SAoT_FS":[],"SAoT_FS_std":[],"SAoT_FS_std0":[],
          "AoT_avg":[],"p_value_AoT":[],"AoT_std":[],"AoT_std0":[]}

# %%
for m in models:
    for c in corpus:
        #for i in range(5):
        data_results1=pd.read_pickle(ruta+m+"/"+c+"/answers/cv1/results.pickle")
        data_results2=pd.read_pickle(ruta+m+"/"+c+"/answers/cv2/results.pickle")
        data_results3=pd.read_pickle(ruta+m+"/"+c+"/answers/cv3/results.pickle")
        data_results4=pd.read_pickle(ruta+m+"/"+c+"/answers/cv4/results.pickle")
        data_results5=pd.read_pickle(ruta+m+"/"+c+"/answers/cv5/results.pickle")
        data_results=pd.concat([data_results1,data_results2,data_results3,data_results4,data_results5],axis=0)
        for la in labels:
            #print(m,c,"CV",i+1)
            #data_results=pd.read_pickle(ruta+m+"/"+c+"/answers/cv"+str(i+1)+"/results.pickle")
            base=data_results[data_results["group"]=="Base"][la]
            base_avg=data_results[data_results["group"]=="Base"][la].mean()
            base_std=data_results[data_results["group"]=="Base"][la].std()
            base_std0=data_results[data_results["group"]=="Base"][la].std(ddof=0)

            gs_dt=data_results[data_results["group"]=="SKA_DT"][la]
            gs_dt_avg=data_results[data_results["group"]=="SKA_DT"][la].mean()
            gs_dt_std=data_results[data_results["group"]=="SKA_DT"][la].std()
            gs_dt_std0=data_results[data_results["group"]=="SKA_DT"][la].std(ddof=0)

            vm=data_results[data_results["group"]=="SKA_MV"][la]
            vm_avg=data_results[data_results["group"]=="SKA_MV"][la].mean()
            vm_std=data_results[data_results["group"]=="SKA_MV"][la].std()
            vm_std0=data_results[data_results["group"]=="SKA_MV"][la].std(ddof=0)

            saot=data_results[data_results["group"]=="SAoT"][la]
            saot_avg=data_results[data_results["group"]=="SAoT"][la].mean()
            saot_std=data_results[data_results["group"]=="SAoT"][la].std()
            saot_std0=data_results[data_results["group"]=="SAoT"][la].std(ddof=0)

            saot_fs=data_results[data_results["group"]=="SAoT_FS"][la]
            saot_fs_avg=data_results[data_results["group"]=="SAoT_FS"][la].mean()
            saot_fs_std=data_results[data_results["group"]=="SAoT_FS"][la].std()
            saot_fs_std0=data_results[data_results["group"]=="SAoT_FS"][la].std(ddof=0)

            aot=data_results[data_results["group"]=="AoT"][la]
            aot_avg=data_results[data_results["group"]=="AoT"][la].mean()
            aot_std=data_results[data_results["group"]=="AoT"][la].std()
            aot_std0=data_results[data_results["group"]=="AoT"][la].std(ddof=0)

            new_data["label"].append(la)
            new_data["model"].append(m)
            new_data["corpus"].append(c)
            new_data["base_avg"].append(base_avg)
            new_data["base_std"].append(base_std)
            new_data["base_std0"].append(base_std0)
            
            new_data["SKA_DT_avg"].append(gs_dt_avg)   
            new_data["p_value_SKA_DT"].append(mannwhitneyu(base, gs_dt).pvalue)
            new_data["SKA_DT_std"].append(gs_dt_std)
            new_data["SKA_DT_std0"].append(gs_dt_std0)

            new_data["SKA_MV_avg"].append(vm_avg)   
            new_data["p_value_SKA_MV"].append(mannwhitneyu(base, vm).pvalue)
            new_data["SKA_MV_std"].append(vm_std)
            new_data["SKA_MV_std0"].append(vm_std0)

            new_data["SAoT_avg"].append(aot_avg)   
            try:
                new_data["p_value_SAoT"].append(mannwhitneyu(base, aot).pvalue)
            except:
                new_data["p_value_SAoT"].append(0)
            new_data["SAoT_std"].append(aot_std)
            new_data["SAoT_std0"].append(aot_std0)

            new_data["SAoT_FS_avg"].append(saot_fs_avg)   
            try:
                new_data["p_value_SAoT_FS"].append(mannwhitneyu(base, saot_fs).pvalue)
            except:
                new_data["p_value_SAoT_FS"].append(0)
            new_data["SAoT_FS_std"].append(saot_fs_std)
            new_data["SAoT_FS_std0"].append(saot_fs_std0)

            new_data["AoT_avg"].append(aot_avg) 
            try:  
                new_data["p_value_AoT"].append(mannwhitneyu(base, aot).pvalue)
            except:
                new_data["p_value_AoT"].append(0)
            new_data["AoT_std"].append(aot_std)
            new_data["AoT_std0"].append(aot_std0)

# %%
temp=pd.DataFrame(new_data)

# %%
temp
# Out:
#           model   corpus      label  base_avg  base_std  base_std0  \
# 0     gemma2:2b  Scitail  Entail_f1  0.788372  0.013982   0.013841
# 1     gemma2:2b  Scitail  Contra_f1  0.686559  0.029364   0.029069
# 2     gemma2:2b  RTEGLUE  Entail_f1  0.753430  0.032669   0.032341
# 3     gemma2:2b  RTEGLUE  Contra_f1  0.736218  0.037027   0.036655
# 4        gemma2  Scitail  Entail_f1  0.825044  0.018403   0.018218
# 5        gemma2  Scitail  Contra_f1  0.768162  0.026345   0.026080
# 6        gemma2  RTEGLUE  Entail_f1  0.885128  0.022853   0.022623
# 7        gemma2  RTEGLUE  Contra_f1  0.865933  0.029870   0.029569
# 8      llama3.2  Scitail  Entail_f1  0.722086  0.019554   0.019358
# 9      llama3.2  Scitail  Contra_f1  0.471055  0.057937   0.057354
# 10     llama3.2  RTEGLUE  Entail_f1  0.760873  0.023527   0.023290
# 11     llama3.2  RTEGLUE  Contra_f1  0.644986  0.044247   0.043802
# 12     llama3.1  Scitail  Entail_f1  0.742751  0.014268   0.014125
# 13     llama3.1  Scitail  Contra_f1  0.488595  0.050346   0.049840
# 14     llama3.1  RTEGLUE  Entail_f1  0.798443  0.017429   0.017254
# 15     llama3.1  RTEGLUE  Contra_f1  0.680199  0.042523   0.042096
# 16  phi3:medium  Scitail  Entail_f1  0.800525  0.018470   0.018285
# 17  phi3:medium  Scitail  Contra_f1  0.692555  0.039325   0.038930
# 18  phi3:medium  RTEGLUE  Entail_f1  0.878871  0.016364   0.016200
# min      6.693235e-18    0.605630    6.650972e-18    0.012994  ...   0.005526
# 25%      1.190319e-14    0.719673    2.401637e-11    0.020288  ...   0.015037
# 50%      5.698975e-03    0.795686    6.024692e-06    0.025154  ...   0.022410
# 75%      3.783907e-01    0.841334    2.330112e-02    0.030881  ...   0.036202
# max      9.752392e-01    0.882899    5.785428e-01    0.046715  ...   0.059628
#
#        SAoT_std0  SAoT_FS_avg  p_value_SAoT_FS  SAoT_FS_std  SAoT_FS_std0  \
# count  24.000000    24.000000     2.400000e+01    24.000000     24.000000
# mean    0.026656     0.730997     1.222971e-01     0.030693      0.030385
# std     0.014374     0.166787     2.477985e-01     0.016892      0.016722
# min     0.005471     0.187452     6.465362e-18     0.007923      0.007843
# 25%     0.014886     0.705435     1.443889e-15     0.020402      0.020197
# 50%     0.022185     0.766211     1.826127e-04     0.026311      0.026047
# 75%     0.035838     0.839572     5.151446e-02     0.036805      0.036435
# max     0.059029     0.886678     9.422491e-01     0.079772      0.078970
#
#          AoT_avg   p_value_AoT    AoT_std   AoT_std0
# count  24.000000  2.400000e+01  24.000000  24.000000
# mean    0.690969  1.150241e-01   0.026927   0.026656
# std     0.195977  2.642899e-01   0.014519   0.014374
# min     0.202186  6.561258e-18   0.005526   0.005471
# 25%     0.625785  6.650972e-18   0.015037   0.014886
# 50%     0.751070  3.429200e-13   0.022410   0.022185
# 75%     0.843573  5.882910e-05   0.036202   0.035838
# max     0.873756  9.532033e-01   0.059628   0.059029
#
# [8 rows x 23 columns]

# %% [markdown]
# temp.columns

# %%
temp.columns
# Out:
# Index(['model', 'corpus', 'label', 'base_avg', 'base_std', 'base_std0',
#        'SKA_DT_avg', 'SKA_DT_std', 'SKA_DT_std0', 'p_value_SKA_DT',
#        'SKA_MV_avg', 'p_value_SKA_MV', 'SKA_MV_std', 'SKA_MV_std0', 'SAoT_avg',
#        'p_value_SAoT', 'SAoT_std', 'SAoT_std0', 'SAoT_FS_avg',
#        'p_value_SAoT_FS', 'SAoT_FS_std', 'SAoT_FS_std0', 'AoT_avg',
#        'p_value_AoT', 'AoT_std', 'AoT_std0'],
#       dtype='object')

# %%
def format_pvalue(p):
    if p < 0.001:
        return "***"
    elif p < 0.01:
        return "**"
    elif p < 0.05:
        return "*"
    else:
        return round(p, 4)

tabla_formateada = temp.copy()
tabla_formateada["p_value_SKA_DT"] = temp["p_value_SKA_DT"].apply(format_pvalue)
tabla_formateada["p_value_SKA_MV"] = temp["p_value_SKA_MV"].apply(format_pvalue)
tabla_formateada["p_value_SAoT"] = temp["p_value_SAoT"].apply(format_pvalue)
tabla_formateada["p_value_SAoT_FS"] = temp["p_value_SAoT_FS"].apply(format_pvalue)
tabla_formateada["p_value_AoT"] = temp["p_value_AoT"].apply(format_pvalue)

tablas_por_corpus = {}
for la in corpus:
    tablas_por_corpus[la] = temp[temp["corpus"] == la].reset_index(drop=True) #.drop(columns=["corpus"])
tablas_por_corpus

#pd.DataFrame(tablas_por_corpus)
# Out:
# {'Scitail':           model   corpus      label  base_avg  base_std  base_std0  \
#  6   0.698380  6.650972e-18  0.009720  0.009622
#  7   0.255851  6.588051e-18  0.053947  0.053405
#  8   0.778274  1.636733e-05  0.015195  0.015042
#  9   0.616199  8.902598e-13  0.038290  0.037905
#  10  0.842030  1.862144e-04  0.013938  0.013798
#  11  0.819340  2.214351e-10  0.019586  0.019389
#
#  [12 rows x 26 columns],
#  'RTEGLUE':           model   corpus      label  base_avg  base_std  base_std0  \
#  0     gemma2:2b  RTEGLUE  Entail_f1  0.753430  0.032669   0.032341
#  1     gemma2:2b  RTEGLUE  Contra_f1  0.736218  0.037027   0.036655
#  2        gemma2  RTEGLUE  Entail_f1  0.885128  0.022853   0.022623
#  3        gemma2  RTEGLUE  Contra_f1  0.865933  0.029870   0.029569
#  4      llama3.2  RTEGLUE  Entail_f1  0.760873  0.023527   0.023290
#  5      llama3.2  RTEGLUE  Contra_f1  0.644986  0.044247   0.043802
#  6      llama3.1  RTEGLUE  Entail_f1  0.798443  0.017429   0.017254
#  7      llama3.1  RTEGLUE  Contra_f1  0.680199  0.042523   0.042096
#  8   phi3:medium  RTEGLUE  Entail_f1  0.878871  0.016364   0.016200
#  9   phi3:medium  RTEGLUE  Contra_f1  0.855156  0.021892   0.021672
#  10         phi3  RTEGLUE  Entail_f1  0.847094  0.039752   0.039352
#  11         phi3  RTEGLUE  Contra_f1  0.852289  0.036618   0.036250
#
#      SKA_DT_avg  SKA_DT_std  SKA_DT_std0  p_value_SKA_DT  ...  SAoT_std  \
#  0     0.752096    0.036449     0.036082    9.752392e-01  ...  0.033983
#  1     0.750036    0.035929     0.035568    5.786306e-02  ...  0.059628
#  2     0.883730    0.022909     0.022679    5.256539e-01  ...  0.023963
#  3     0.875412    0.028460     0.028174    1.352433e-02  ...  0.032155
#  4     0.764361    0.019972     0.019771    4.155800e-01  ...  0.014564
#  5     0.722088    0.030867     0.030557    2.116485e-12  ...  0.049449
#  6     0.808636    0.021042     0.020830    1.058500e-02  ...  0.011439
#  7     0.775384    0.032751     0.032422    2.201722e-15  ...  0.035532
#  8     0.874484    0.027561     0.027284    9.011496e-01  ...  0.020858
#  9     0.854105    0.030623     0.030316    5.166491e-01  ...  0.038211
#  10    0.847415    0.027777     0.027498    3.659942e-01  ...  0.020481
#  11    0.855042    0.026910     0.026639    7.666699e-01  ...  0.018986
#
#      SAoT_std0  SAoT_FS_avg  p_value_SAoT_FS  SAoT_FS_std  SAoT_FS_std0  \
#  0    0.033642     0.402613     6.610458e-18     0.071048      0.070334
#  1    0.059029     0.713353     1.267961e-04     0.018068      0.017887
#  2    0.023722     0.886678     3.087101e-01     0.020609      0.020402
#  3    0.031832     0.884892     3.548092e-03     0.021778      0.021559
#  4    0.014417     0.742306     2.438164e-04     0.022711      0.022483
#  5    0.048952     0.646309     6.095294e-01     0.036587      0.036220
#  6    0.011324     0.813892     1.286554e-03     0.024554      0.024307
#  7    0.035175     0.738097     2.547851e-09     0.042783      0.042353
#  8    0.020648     0.877422     4.623103e-01     0.027401      0.027126
#  9    0.037827     0.856361     1.954136e-01     0.037459      0.037083
#  10   0.020275     0.732993     4.398229e-16     0.045380      0.044924
#  11   0.018795     0.766874     1.550768e-14     0.033182      0.032848
#
#       AoT_avg   p_value_AoT   AoT_std  AoT_std0
#  0   0.747743  4.966490e-01  0.033983  0.033642
#  1   0.628981  6.357225e-13  0.059628  0.059029
#  2   0.873756  8.363804e-02  0.023963  0.023722
#  3   0.857315  5.456600e-01  0.032155  0.031832
#  4   0.693196  6.588051e-18  0.014564  0.014417
#  5   0.310747  6.588051e-18  0.049449  0.048952
#  6   0.754397  1.576069e-17  0.011439  0.011324
#  7   0.537598  6.650972e-18  0.035532  0.035175
#  8   0.848201  1.195871e-11  0.020858  0.020648
#  9   0.789467  5.011741e-14  0.038211  0.037827
#  10  0.850020  6.812245e-01  0.020481  0.020275
#  11  0.859516  9.532033e-01  0.018986  0.018795
#
#  [12 rows x 26 columns]}

# %%
# Crea una tabla agrupada por modelo y corpus, promediando los valores numéricos
tabla_por_corpus = temp[["model",  "label", "corpus",
                                             "base_avg", "base_std",
                                             "SKA_DT_avg", "p_value_SKA_DT","SKA_DT_std",
                                             "SKA_MV_avg", "p_value_SKA_MV", "SKA_MV_std",
                                             "SAoT_avg", "p_value_SAoT", "SAoT_std",
                                             "AoT_avg", "p_value_AoT", "AoT_std",
                                             "SAoT_FS_avg", "p_value_SAoT_FS","SAoT_FS_std"]].copy()

# Multiplica base_avg y DT_avg por 100 y redondea a 1 decimal
tabla_por_corpus["Base"] = (tabla_por_corpus["base_avg"] * 100).round(1)
tabla_por_corpus["SKA_DT"] = (tabla_por_corpus["SKA_DT_avg"] * 100).round(1)
tabla_por_corpus["SKA_MV"] = (tabla_por_corpus["SKA_MV_avg"] * 100).round(1)
tabla_por_corpus["SAoT"] = (tabla_por_corpus["SAoT_avg"] * 100).round(1)
tabla_por_corpus["SAoT_FS"] = (tabla_por_corpus["SAoT_FS_avg"] * 100).round(1)
tabla_por_corpus["AoT"] = (tabla_por_corpus["AoT_avg"] * 100).round(1)

# Formatea el p_value según los criterios dados
def format_pvalue(p):
    if p < 0.001:
        return "***"
    elif p < 0.01:
        return "**"
    elif p < 0.05:
        return "*"
    else:
        return round(p, 4)

tabla_por_corpus["p_value_SKA_DT"] = tabla_por_corpus.apply(lambda x: "" if x['Base']>=x['SKA_DT'] else format_pvalue(x['p_value_SKA_DT']), axis=1)
tabla_por_corpus["p_value_SKA_MV"] = tabla_por_corpus.apply(lambda x: "" if x['Base']>=x['SKA_MV'] else format_pvalue(x['p_value_SKA_MV']), axis=1)
tabla_por_corpus["p_value_SAoT"] = tabla_por_corpus.apply(lambda x: "" if x['Base']>=x['SAoT'] else format_pvalue(x['p_value_SAoT']), axis=1)
tabla_por_corpus["p_value_SAoT_FS"] = tabla_por_corpus.apply(lambda x: "" if x['Base']>=x['SAoT_FS'] else format_pvalue(x['p_value_SAoT_FS']), axis=1)
tabla_por_corpus["p_value_AoT"] = tabla_por_corpus.apply(lambda x: "" if x['Base']>=x['AoT'] else format_pvalue(x['p_value_AoT']), axis=1)

# tabla_por_corpus["p_value_dt"] = tabla_por_corpus["p_value_dt"].apply(format_pvalue)
# tabla_por_corpus["p_value_vm"] = tabla_por_corpus["p_value_vm"].apply(format_pvalue)
# tabla_por_corpus["p_value_aot"] = tabla_por_corpus["p_value_aot"].apply(format_pvalue)
# tabla_por_corpus["p_value_cot"] = tabla_por_corpus["p_value_cot"].apply(format_pvalue)
# tabla_por_corpus["p_value_aot_fs"] = tabla_por_corpus["p_value_aot_fs"].apply(format_pvalue)

tabla_por_corpus2=tabla_por_corpus[["model", "corpus","label", "Base","AoT", "p_value_AoT","SAoT", "p_value_AoT", "SAoT_FS", "p_value_SAoT_FS",
                   "SKA_MV","p_value_SKA_MV", "SKA_DT", "p_value_SKA_DT","base_std","AoT_std","SKA_DT_std","SKA_MV_std","SAoT_std","SAoT_FS_std"]]

# %%
orden_modelos= ['gemma2', 'gemma2:2b', 'llama3.1','llama3.2','phi3:medium','phi3']

# %%
# Ordena el DataFrame primero por 'corpus' y luego por el orden de los modelos
tabla_ordenada_por_corpus = tabla_por_corpus2.sort_values(
    by=[ 'model','corpus','label'], 
    key=lambda col: col if col.name != 'model' else col.map({model: i for i, model in enumerate(orden_modelos)})
).reset_index(drop=True)

tabla_ordenada_por_corpus
# Out:
#           model   corpus      label  Base   AoT p_value_AoT  SAoT p_value_AoT  \
# 0        gemma2  RTEGLUE  Contra_f1  86.6  85.7              85.7
# 1        gemma2  RTEGLUE  Entail_f1  88.5  87.4              87.4
# 2        gemma2  Scitail  Contra_f1  76.8  82.2         ***  82.2         ***
# 3        gemma2  Scitail  Entail_f1  82.5  85.1         ***  85.1         ***
# 4     gemma2:2b  RTEGLUE  Contra_f1  73.6  62.9              62.9
# 5     gemma2:2b  RTEGLUE  Entail_f1  75.3  74.8              74.8
# 6     gemma2:2b  Scitail  Contra_f1  68.7  52.1              52.1
# 7     gemma2:2b  Scitail  Entail_f1  78.8  74.1              74.1
# 8      llama3.1  RTEGLUE  Contra_f1  68.0  53.8              53.8
# 9      llama3.1  RTEGLUE  Entail_f1  79.8  75.4              75.4
# 10     llama3.1  Scitail  Contra_f1  48.9  25.6              25.6
# 11     llama3.1  Scitail  Entail_f1  74.3  69.8              69.8
# 12     llama3.2  RTEGLUE  Contra_f1  64.5  31.1              31.1
# 13     llama3.2  RTEGLUE  Entail_f1  76.1  69.3              69.3
# 14     llama3.2  Scitail  Contra_f1  47.1  20.2              20.2
# 15     llama3.2  Scitail  Entail_f1  72.2  68.6              68.6
# 16  phi3:medium  RTEGLUE  Contra_f1  85.5  78.9              78.9
# 17  phi3:medium  RTEGLUE  Entail_f1  87.9  84.8              84.8
# 18  phi3:medium  Scitail  Contra_f1  69.3  61.6              61.6
# 19  phi3:medium  Scitail  Entail_f1  80.1  77.8              77.8
# 20         phi3  RTEGLUE  Contra_f1  85.2  86.0      0.9532  86.0      0.9532
# 21         phi3  RTEGLUE  Entail_f1  84.7  85.0      0.6812  85.0      0.6812
# 22         phi3  Scitail  Contra_f1  78.9  81.9         ***  81.9         ***
# 23         phi3  Scitail  Entail_f1  83.1  84.2         ***  84.2         ***
#
#     SAoT_FS p_value_SAoT_FS  SKA_MV p_value_SKA_MV  SKA_DT p_value_SKA_DT  \
# 0      88.5              **    87.0         0.1172    87.5              *
# 1      88.7          0.3087    88.3                   88.4
# 2      85.2             ***    82.7            ***    84.4            ***
# 3      86.5             ***    85.3            ***    85.0            ***
# 4      71.3                    75.3             **    75.0         0.0579
# 5      40.3                    70.2                   75.2
# 6      76.6             ***    76.4            ***    76.2            ***
# 7      82.7             ***    78.2                   79.4          0.093
# 8      73.8             ***    71.7            ***    77.5            ***
# 9      81.4              **    81.0             **    80.9              *
# 10     48.8                    60.6            ***    74.8            ***
# 11     74.0                    77.5            ***    79.1            ***
# 12     64.6          0.6095    72.1            ***    72.2            ***
# 13     74.2                    71.4                   76.4         0.4156
# 14     18.7                    71.3            ***    73.7            ***
# 15     68.2                    74.5            ***    72.2
# 16     85.6          0.1954    84.1                   85.4
# 17     87.7                    87.3                   87.4
# 18     63.4                    71.4         0.0582    76.4            ***
# 19     78.7                    81.2              *    83.1            ***
# 20     76.7                    84.3                   85.5         0.7667
# 21     73.3                    81.5                   84.7
# 22     83.5             ***    82.4            ***    83.7            ***
# 23     82.0                    84.3            ***    84.2            ***
#
#     base_std   AoT_std  SKA_DT_std  SKA_MV_std  SAoT_std  SAoT_FS_std
# 0   0.029870  0.032155    0.028460    0.034248  0.032155     0.021778
# 1   0.022853  0.023963    0.022909    0.026187  0.023963     0.020609
# 2   0.026345  0.024430    0.018906    0.021873  0.024430     0.025221
# 3   0.018403  0.020506    0.016393    0.018666  0.020506     0.019268
# 4   0.037027  0.059628    0.035929    0.025861  0.059628     0.018068
# 5   0.032669  0.033983    0.036449    0.038411  0.033983     0.071048
# 6   0.029364  0.042404    0.024756    0.020930  0.042404     0.029211
# 7   0.013982  0.013480    0.020363    0.018809  0.013480     0.016330
# 8   0.042523  0.035532    0.032751    0.039391  0.035532     0.042783
# 9   0.017429  0.011439    0.021042    0.020126  0.011439     0.024554
# 10  0.050346  0.053947    0.031379    0.035470  0.053947     0.043007
# 11  0.014268  0.009720    0.020136    0.012994  0.009720     0.010995
# 12  0.044247  0.049449    0.030867    0.029559  0.049449     0.036587
# 13  0.023527  0.014564    0.019972    0.032236  0.014564     0.022711
# 14  0.057937  0.029975    0.016309    0.025185  0.029975     0.032880
# 15  0.019554  0.005526    0.021167    0.024015  0.005526     0.007923
# 16  0.021892  0.038211    0.030623    0.030429  0.038211     0.037459
# 17  0.016364  0.020858    0.027561    0.020342  0.020858     0.027401
# 18  0.039325  0.038290    0.039757    0.046715  0.038290     0.079772
# 19  0.018470  0.015195    0.022643    0.022477  0.015195     0.028178
# 20  0.036618  0.018986    0.026910    0.025122  0.018986     0.033182
# 21  0.039752  0.020481    0.027777    0.029408  0.020481     0.045380
# 22  0.023466  0.019586    0.017116    0.019397  0.019586     0.019780
# 23  0.015439  0.013938    0.015643    0.014932  0.013938     0.022515

# %%
tabla_ordenada_por_corpus["Base"] = tabla_ordenada_por_corpus["Base"].astype(str) + " ± " + (tabla_ordenada_por_corpus["base_std"]*100).round(2).astype(str)
tabla_ordenada_por_corpus["SKA_DT"] = tabla_ordenada_por_corpus["SKA_DT"].astype(str) + " ± " + (tabla_ordenada_por_corpus["SKA_DT_std"]*100).round(2).astype(str)
tabla_ordenada_por_corpus["SAoT"] = tabla_ordenada_por_corpus["SAoT"].astype(str) + " ± " + (tabla_ordenada_por_corpus["SAoT_std"]*100).round(2).astype(str)
tabla_ordenada_por_corpus["SAoT_FS"] = tabla_ordenada_por_corpus["SAoT_FS"].astype(str) + " ± " + (tabla_ordenada_por_corpus["SAoT_FS_std"]*100).round(2).astype(str)
tabla_ordenada_por_corpus["AoT"] = tabla_ordenada_por_corpus["AoT"].astype(str) + " ± " + (tabla_ordenada_por_corpus["AoT_std"]*100).round(2).astype(str)
tabla_ordenada_por_corpus["SKA_VM"] = tabla_ordenada_por_corpus["SKA_MV"].astype(str) + " ± " + (tabla_ordenada_por_corpus["SKA_MV_std"]*100).round(2).astype(str)

tabla_ordenada_por_corpus
# Out:
#           model   corpus      label         Base          AoT p_value_AoT  \
# 0        gemma2  RTEGLUE  Contra_f1  86.6 ± 2.99  85.7 ± 3.22
# 1        gemma2  RTEGLUE  Entail_f1  88.5 ± 2.29   87.4 ± 2.4
# 2        gemma2  Scitail  Contra_f1  76.8 ± 2.63  82.2 ± 2.44         ***
# 3        gemma2  Scitail  Entail_f1  82.5 ± 1.84  85.1 ± 2.05         ***
# 4     gemma2:2b  RTEGLUE  Contra_f1   73.6 ± 3.7  62.9 ± 5.96
# 5     gemma2:2b  RTEGLUE  Entail_f1  75.3 ± 3.27   74.8 ± 3.4
# 6     gemma2:2b  Scitail  Contra_f1  68.7 ± 2.94  52.1 ± 4.24
# 7     gemma2:2b  Scitail  Entail_f1   78.8 ± 1.4  74.1 ± 1.35
# 8      llama3.1  RTEGLUE  Contra_f1  68.0 ± 4.25  53.8 ± 3.55
# 9      llama3.1  RTEGLUE  Entail_f1  79.8 ± 1.74  75.4 ± 1.14
# 10     llama3.1  Scitail  Contra_f1  48.9 ± 5.03  25.6 ± 5.39
# 11     llama3.1  Scitail  Entail_f1  74.3 ± 1.43  69.8 ± 0.97
# 12     llama3.2  RTEGLUE  Contra_f1  64.5 ± 4.42  31.1 ± 4.94
# 13     llama3.2  RTEGLUE  Entail_f1  76.1 ± 2.35  69.3 ± 1.46
# 14     llama3.2  Scitail  Contra_f1  47.1 ± 5.79   20.2 ± 3.0
# 15     llama3.2  Scitail  Entail_f1  72.2 ± 1.96  68.6 ± 0.55
# 16  phi3:medium  RTEGLUE  Contra_f1  85.5 ± 2.19  78.9 ± 3.82
# 17  phi3:medium  RTEGLUE  Entail_f1  87.9 ± 1.64  84.8 ± 2.09
# 18  phi3:medium  Scitail  Contra_f1  69.3 ± 3.93  61.6 ± 3.83
# 19  phi3:medium  Scitail  Entail_f1  80.1 ± 1.85  77.8 ± 1.52
# 20         phi3  RTEGLUE  Contra_f1  85.2 ± 3.66   86.0 ± 1.9      0.9532
# 21         phi3  RTEGLUE  Entail_f1  84.7 ± 3.98  85.0 ± 2.05      0.6812
# 22         phi3  Scitail  Contra_f1  78.9 ± 2.35  81.9 ± 1.96         ***
# 23         phi3  Scitail  Entail_f1  83.1 ± 1.54  84.2 ± 1.39         ***
#
#            SAoT p_value_AoT      SAoT_FS p_value_SAoT_FS  ...  p_value_SKA_MV  \
# 0   85.7 ± 3.22              88.5 ± 2.18              **  ...          0.1172
# 1    87.4 ± 2.4              88.7 ± 2.06          0.3087  ...
# 2   82.2 ± 2.44         ***  85.2 ± 2.52             ***  ...             ***
# 3   85.1 ± 2.05         ***  86.5 ± 1.93             ***  ...             ***
# 4   62.9 ± 5.96              71.3 ± 1.81                  ...              **
# 5    74.8 ± 3.4               40.3 ± 7.1                  ...
# 6   52.1 ± 4.24              76.6 ± 2.92             ***  ...             ***
# 7   74.1 ± 1.35              82.7 ± 1.63             ***  ...
# 8   53.8 ± 3.55              73.8 ± 4.28             ***  ...             ***
# 9   75.4 ± 1.14              81.4 ± 2.46              **  ...              **
# 10  25.6 ± 5.39               48.8 ± 4.3                  ...             ***
# 11  69.8 ± 0.97               74.0 ± 1.1                  ...             ***
# 12  31.1 ± 4.94              64.6 ± 3.66          0.6095  ...             ***
# 13  69.3 ± 1.46              74.2 ± 2.27                  ...
# 14   20.2 ± 3.0              18.7 ± 3.29                  ...             ***
# 15  68.6 ± 0.55              68.2 ± 0.79                  ...             ***
# 16  78.9 ± 3.82              85.6 ± 3.75          0.1954  ...
# 17  84.8 ± 2.09              87.7 ± 2.74                  ...
# 18  61.6 ± 3.83              63.4 ± 7.98                  ...          0.0582
# 19  77.8 ± 1.52              78.7 ± 2.82                  ...               *
# 20   86.0 ± 1.9      0.9532  76.7 ± 3.32                  ...
# 21  85.0 ± 2.05      0.6812  73.3 ± 4.54                  ...
# 22  81.9 ± 1.96         ***  83.5 ± 1.98             ***  ...             ***
# 23  84.2 ± 1.39         ***  82.0 ± 2.25                  ...             ***
#
#          SKA_DT p_value_SKA_DT  base_std   AoT_std  SKA_DT_std  SKA_MV_std  \
# 0   87.5 ± 2.85              *  0.029870  0.032155    0.028460    0.034248
# 1   88.4 ± 2.29                 0.022853  0.023963    0.022909    0.026187
# 2   84.4 ± 1.89            ***  0.026345  0.024430    0.018906    0.021873
# 3   85.0 ± 1.64            ***  0.018403  0.020506    0.016393    0.018666
# 4   75.0 ± 3.59         0.0579  0.037027  0.059628    0.035929    0.025861
# 5   75.2 ± 3.64                 0.032669  0.033983    0.036449    0.038411
# 6   76.2 ± 2.48            ***  0.029364  0.042404    0.024756    0.020930
# 7   79.4 ± 2.04          0.093  0.013982  0.013480    0.020363    0.018809
# 8   77.5 ± 3.28            ***  0.042523  0.035532    0.032751    0.039391
# 9    80.9 ± 2.1              *  0.017429  0.011439    0.021042    0.020126
# 10  74.8 ± 3.14            ***  0.050346  0.053947    0.031379    0.035470
# 11  79.1 ± 2.01            ***  0.014268  0.009720    0.020136    0.012994
# 12  72.2 ± 3.09            ***  0.044247  0.049449    0.030867    0.029559
# 13   76.4 ± 2.0         0.4156  0.023527  0.014564    0.019972    0.032236
# 14  73.7 ± 1.63            ***  0.057937  0.029975    0.016309    0.025185
# 15  72.2 ± 2.12                 0.019554  0.005526    0.021167    0.024015
# 16  85.4 ± 3.06                 0.021892  0.038211    0.030623    0.030429
# 17  87.4 ± 2.76                 0.016364  0.020858    0.027561    0.020342
# 18  76.4 ± 3.98            ***  0.039325  0.038290    0.039757    0.046715
# 19  83.1 ± 2.26            ***  0.018470  0.015195    0.022643    0.022477
# 20  85.5 ± 2.69         0.7667  0.036618  0.018986    0.026910    0.025122
# 21  84.7 ± 2.78                 0.039752  0.020481    0.027777    0.029408
# 22  83.7 ± 1.71            ***  0.023466  0.019586    0.017116    0.019397
# 23  84.2 ± 1.56            ***  0.015439  0.013938    0.015643    0.014932
#
#     SAoT_std  SAoT_FS_std       SKA_VM
# 0   0.032155     0.021778  87.0 ± 3.42
# 1   0.023963     0.020609  88.3 ± 2.62
# 2   0.024430     0.025221  82.7 ± 2.19
# 3   0.020506     0.019268  85.3 ± 1.87
# 4   0.059628     0.018068  75.3 ± 2.59
# 5   0.033983     0.071048  70.2 ± 3.84
# 6   0.042404     0.029211  76.4 ± 2.09
# 7   0.013480     0.016330  78.2 ± 1.88
# 8   0.035532     0.042783  71.7 ± 3.94
# 9   0.011439     0.024554  81.0 ± 2.01
# 10  0.053947     0.043007  60.6 ± 3.55
# 11  0.009720     0.010995   77.5 ± 1.3
# 12  0.049449     0.036587  72.1 ± 2.96
# 13  0.014564     0.022711  71.4 ± 3.22
# 14  0.029975     0.032880  71.3 ± 2.52
# 15  0.005526     0.007923   74.5 ± 2.4
# 16  0.038211     0.037459  84.1 ± 3.04
# 17  0.020858     0.027401  87.3 ± 2.03
# 18  0.038290     0.079772  71.4 ± 4.67
# 19  0.015195     0.028178  81.2 ± 2.25
# 20  0.018986     0.033182  84.3 ± 2.51
# 21  0.020481     0.045380  81.5 ± 2.94
# 22  0.019586     0.019780  82.4 ± 1.94
# 23  0.013938     0.022515  84.3 ± 1.49
#
# [24 rows x 21 columns]

# %%
tabla_ordenada_por_corpus[(tabla_ordenada_por_corpus["model"]=="phi3") & (tabla_ordenada_por_corpus["corpus"]=="RTEGLUE")]
# Out:
#    model   corpus      label         Base          AoT p_value_AoT  \
# 20  phi3  RTEGLUE  Contra_f1  85.2 ± 3.66   86.0 ± 1.9      0.9532
# 21  phi3  RTEGLUE  Entail_f1  84.7 ± 3.98  85.0 ± 2.05      0.6812
#
#            SAoT p_value_AoT      SAoT_FS p_value_SAoT_FS  ...  p_value_SKA_MV  \
# 20   86.0 ± 1.9      0.9532  76.7 ± 3.32                  ...
# 21  85.0 ± 2.05      0.6812  73.3 ± 4.54                  ...
#
#          SKA_DT p_value_SKA_DT  base_std   AoT_std  SKA_DT_std  SKA_MV_std  \
# 20  85.5 ± 2.69         0.7667  0.036618  0.018986    0.026910    0.025122
# 21  84.7 ± 2.78                 0.039752  0.020481    0.027777    0.029408
#
#     SAoT_std  SAoT_FS_std       SKA_VM
# 20  0.018986     0.033182  84.3 ± 2.51
# 21  0.020481     0.045380  81.5 ± 2.94
#
# [2 rows x 21 columns]
